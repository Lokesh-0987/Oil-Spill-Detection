# %%
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')

# Load AIS data (example CSV with vessel details and positions)
ais_data = pd.read_csv('AIS_2024_01_23.csv')

# Convert BaseDateTime to datetime format for time-based sorting
ais_data['BaseDateTime'] = pd.to_datetime(ais_data['BaseDateTime'])

# Sort by MMSI and BaseDateTime to analyze each vessel's movement sequentially
ais_data = ais_data.sort_values(['MMSI', 'BaseDateTime'])

# Detect anomalies in AIS data based on speed and course changes
# Detect anomalies in AIS data based on relative speed changes and course changes
def detect_anomalies(df):
    anomalies = []
    unique_vessels = df['MMSI'].unique()

    for vessel in unique_vessels:
        vessel_data = df[df['MMSI'] == vessel].reset_index(drop=True)

        for i in range(1, len(vessel_data)):
            previous_speed = vessel_data['SOG'].iloc[i - 1]
            current_speed = vessel_data['SOG'].iloc[i]
            speed_change = abs(current_speed - previous_speed)
            course_change = abs(vessel_data['COG'].iloc[i] - vessel_data['COG'].iloc[i - 1])

            # Detect speed anomalies based on a 50% change relative to the previous speed
            if previous_speed >= 20 and speed_change > 0.45 * previous_speed and course_change > 30:
                anomalies.append(vessel_data.iloc[i])
            # Detect course anomalies
            #elif previous_speed >= 30 and course_change > 30:
                #anomalies.append(vessel_data.iloc[i])

    return pd.DataFrame(anomalies)

# Detect anomalies
anomalies_df = detect_anomalies(ais_data)
print("Anomalies detected:")
print(anomalies_df)
# Out:
# Anomalies detected:
#           MMSI        BaseDateTime       LAT       LON   SOG    COG  Heading  \
# 100  200014202 2024-01-23 14:21:54  29.60747 -89.88319   0.0   43.5    511.0
# 298  200014202 2024-01-23 21:19:23  29.60596 -89.87661   0.0  169.7    511.0
# 87   232142000 2024-01-23 05:20:14  25.54057 -78.80176  45.3  221.4    511.0
# 88   232142000 2024-01-23 05:44:06  25.80934 -80.16882   8.5  329.8    511.0
# 168  232142000 2024-01-23 08:18:54  29.69324 -82.96946  80.3   19.0    511.0
# ..         ...                 ...       ...       ...   ...    ...      ...
# 259  982000000 2024-01-23 11:51:22  29.54384 -89.76753   2.4  267.7    511.0
# 385  982000000 2024-01-23 16:19:50  29.60327 -89.84782   5.4   61.0    511.0
# 401  982000000 2024-01-23 16:37:39  29.60552 -89.85261   1.7  127.3    511.0
# 439  982000000 2024-01-23 17:50:26  29.60512 -89.85257   1.8  299.9    511.0
# 595  982000000 2024-01-23 22:38:19  29.54421 -89.76861   0.7  249.8    511.0
#
#               VesselName         IMO CallSign  VesselType  Status  Length  \
# 100  WEEKS CONST CREW BT  IMO0000000      NaN        90.0     NaN    10.0
# 298  WEEKS CONST CREW BT  IMO0000000      NaN        90.0     NaN    10.0
# 87              SI SI SI  IMO1003970     GGHS        37.0     NaN    29.0
# 88              SI SI SI  IMO1003970     GGHS        37.0     NaN    29.0
# 168             SI SI SI  IMO1003970     GGHS        37.0     NaN    29.0
# ..                   ...         ...      ...         ...     ...     ...
# 259                RBS11  IMO0000000    RBS11        37.0     0.0     7.0
# 385                RBS11  IMO0000000    RBS11        37.0     0.0     7.0
# 401                RBS11  IMO0000000    RBS11        37.0     0.0     7.0
# 439                RBS11  IMO0000000    RBS11        37.0     0.0     7.0
# 595                RBS11  IMO0000000    RBS11        37.0     0.0     7.0
#
#      Width  Draft  Cargo TransceiverClass
# 100    3.0    NaN    NaN                B
# 298    3.0    NaN    NaN                B
# 87     7.0    NaN    NaN                B
# 88     7.0    NaN    NaN                B
# 168    7.0    NaN    NaN                B
# ..     ...    ...    ...              ...
# 259    2.0    0.0   50.0                A
# 385    2.0    0.0   50.0                A
# 401    2.0    0.0   50.0                A
# 439    2.0    0.0   50.0                A
# 595    2.0    0.0   50.0                A
#
# [2399 rows x 17 columns]

# %%
# Install necessary packages
# !pip install geemap
# !pip install earthengine-api
# Install Earth Engine and Geemap
# !pip install earthengine-api geemap


# Authenticate and initialize Earth Engine
import ee
import geemap

# Trigger the authentication
ee.Authenticate()

# Initialize the Earth Engine API
ee.Initialize(project='ee-oilspilldetectionharshasri')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geemap in c:\users\harsh\appdata\roaming\python\python312\site-packages (0.35.0)
# Requirement already satisfied: bqplot in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.12.43)
# Requirement already satisfied: colour in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=1.0.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (1.1.5)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.17.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.18.0)
# Requirement already satisfied: geocoder in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (3.9.0)
# Requirement already satisfied: numpy in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (2.2.2)
# Requirement already satisfied: plotly in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (5.22.0)
# Requirement already satisfied: pyperclip in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (7.2.0)
# Requirement already satisfied: scooby in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: google-cloud-storage in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api>=1.0.0->geemap) (2.18.2)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api>=1.0.0->geemap) (2.149.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api>=1.0.0->geemap) (2.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api>=1.0.0->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api>=1.0.0->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api>=1.0.0->geemap) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from folium>=0.17.0->geemap) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from folium>=0.17.0->geemap) (3.1.4)
# Requirement already satisfied: xyzservices in c:\users\harsh\appdata\roaming\python\python312\site-packages (from folium>=0.17.0->geemap) (2024.9.0)
# Requirement already satisfied: ipywidgets in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.3)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pandas->geemap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pandas->geemap) (2024.1)
# Requirement already satisfied: click in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (8.1.7)
# Requirement already satisfied: future in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from plotly->geemap) (8.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (2.21.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.9)
# Requirement already satisfied: comm>=0.1.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (2.1.5)
# Requirement already satisfied: colorama in c:\users\harsh\appdata\roaming\python\python312\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2024.6.2)
# Requirement already satisfied: decorator in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (5.28.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.25.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.46)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\harsh\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\harsh\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: earthengine-api in c:\users\harsh\appdata\roaming\python\python312\site-packages (1.1.5)
# Requirement already satisfied: google-cloud-storage in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.18.2)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.149.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.21.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.1.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (2024.6.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (5.28.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.25.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: earthengine-api in c:\users\harsh\appdata\roaming\python\python312\site-packages (1.1.5)
# Requirement already satisfied: geemap in c:\users\harsh\appdata\roaming\python\python312\site-packages (0.35.0)
# Requirement already satisfied: google-cloud-storage in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.18.2)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.149.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\harsh\appdata\roaming\python\python312\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: bqplot in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.12.43)
# Requirement already satisfied: colour in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.17.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.18.0)
# Requirement already satisfied: geocoder in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (3.9.0)
# Requirement already satisfied: numpy in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (2.2.2)
# Requirement already satisfied: plotly in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (5.22.0)
# Requirement already satisfied: pyperclip in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (7.2.0)
# Requirement already satisfied: scooby in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from folium>=0.17.0->geemap) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from folium>=0.17.0->geemap) (3.1.4)
# Requirement already satisfied: xyzservices in c:\users\harsh\appdata\roaming\python\python312\site-packages (from folium>=0.17.0->geemap) (2024.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.21.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.1.2)
# Requirement already satisfied: ipywidgets in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.3)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pandas->geemap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pandas->geemap) (2024.1)
# Requirement already satisfied: click in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (8.1.7)
# Requirement already satisfied: future in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\harsh\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-cloud-storage->earthengine-api) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from requests->earthengine-api) (2024.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (10.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from plotly->geemap) (8.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (5.28.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.25.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: colorama in c:\users\harsh\appdata\roaming\python\python312\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: decorator in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.46)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\harsh\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\harsh\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\harsh\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_0JLhFqfSY1uiEaW?source=Init

# %%
def plot_histogram(image, region, title):
    try:
        array = image.reduceRegion(
            reducer=ee.Reducer.toList(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).get('VV')

        # Check if array is empty
        if array is None:
            print("No VV data available for histogram plot.")
            return

        array = np.array(array.getInfo())
        plt.hist(array, bins=50, color='blue', alpha=0.7)
        plt.title(title)
        plt.xlabel('VV (dB)')
        plt.ylabel('Frequency')
        plt.grid()
        plt.show()
    except Exception as e:
        print(f"Error plotting histogram: {e}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from datetime import datetime

# Function to parse date from BaseDateTime
def extract_date(base_date_time):
    # Convert to string if it’s a Timestamp
    if isinstance(base_date_time, pd.Timestamp):
        base_date_time = base_date_time.strftime('%Y-%m-%dT%H:%M:%S')
    else:
        base_date_time = str(base_date_time)

    # Parse the date
    date_time_obj = datetime.strptime(base_date_time, '%Y-%m-%dT%H:%M:%S')
    return date_time_obj.strftime('%Y-%m-%d')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import tensorflow as tf

# Define jaccard_coef if not already defined
def jaccard_coef(y_true, y_pred):
    y_true_flatten = tf.reshape(y_true, [-1])
    y_pred_flatten = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_flatten * y_pred_flatten)
    sum_ = tf.reduce_sum(y_true_flatten) + tf.reduce_sum(y_pred_flatten)
    smooth = 1e-6  # To avoid division by zero
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from tensorflow.keras.models import load_model
import os

# Ensure segmentation_models uses TensorFlow backend
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

# Load the models
hybrid_model = load_model(r"C:\Users\harsh\OneDrive\Desktop\Capstone\hybrid_model.h5")
unet_model = load_model(r"C:\Users\harsh\OneDrive\Desktop\Capstone\U_net.h5")
deeplab_model = load_model(
    r"C:\Users\harsh\OneDrive\Desktop\Capstone\deeplab_model.h5",
    custom_objects={
        "jaccard_coef": jaccard_coef,  # Ensure this function is defined in your script
        "DiceLoss": sm.losses.DiceLoss(),  # Initialize the DiceLoss object
        "CategoricalFocalLoss": sm.losses.CategoricalFocalLoss()  # Initialize the CategoricalFocalLoss object
    }
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Segmentation Models: using `tf.keras` framework.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def preprocess_image_for_model(image_np):
    """ Preprocess the NumPy array image to match model input requirements """
    # Remove any extra dimensions if present (e.g., shape (256, 256, 1, 6) -> (256, 256, 2))
    if image_np.ndim == 4:
        image_np = image_np[:, :, :, 0]

    # Resize to 256x256
    resized_image = cv2.resize(image_np, (256, 256))

    # Ensure the image has three channels (duplicate one if necessary)
    if resized_image.shape[-1] == 2:
        resized_image = np.repeat(resized_image[:, :, :1], 3, axis=-1)
    elif resized_image.shape[-1] == 1:
        resized_image = np.repeat(resized_image, 3, axis=-1)

    # Add batch dimension
    return np.expand_dims(resized_image, axis=0)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def confirm_oil_spill(hybrid_model, unet_model, deeplab_model, image):
    """ 
    Confirm oil spill detection using Hybrid, UNet, and DeepLabV3+ models. 
    Requires agreement among all models.
    """
    processed_image = preprocess_image_for_model(image)

    #processed_image = preprocess_image_for_model(image)
        
        # Get predictions from both models
    unet_prediction = unet_model.predict(processed_image)
    deeplab_prediction = deeplab_model.predict(processed_image)
    hybrid_prediction = hybrid_model.predict(processed_image)

    # Assuming '1' corresponds to oil spill for both models
    unet_result = np.argmax(unet_prediction) == 1
    deeplab_result = np.argmax(deeplab_prediction) == 1
    hybrid_result = np.argmax(hybrid_prediction) == 1

    # Confirm only if both models agree
    #return unet_result 

    # Confirm only if all models agree
    return hybrid_result and unet_result and deeplab_result
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from tensorflow.keras.models import load_model
import geemap
import ee
import numpy as np
import cv2
from IPython.display import display

def process_anomaly(row):
    lat = row['LAT']
    lon = row['LON']
    base_date_time = row['BaseDateTime']
    date = extract_date(base_date_time)
    anomaly_date = ee.Date(date)
    print(f"Processing anomaly at {lat}, {lon} on {date}")

    roi = ee.Geometry.Point(lon, lat).buffer(10000).bounds()
    detected_spills = []

    # Sentinel-1 collection
    sen1 = ee.ImageCollection("COPERNICUS/S1_GRD") \
        .filterDate(anomaly_date, anomaly_date.advance(1, 'day')) \
        .filterBounds(roi) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH')) \
        .filter(ee.Filter.eq('instrumentMode', 'IW'))
    # for x in sen1.size():
    #     print(x)

    if sen1.size().getInfo() == 0:
        print("No Sentinel-1 VV or VH images available. Trying Sentinel-2.")
        sen1 = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") \
            .filterDate(anomaly_date, anomaly_date.advance(1, 'day')) \
            .filterBounds(roi) \
            .filter(ee.Filter.eq('CLOUDY_PIXEL_PERCENTAGE', 0))

        if sen1.size().getInfo() == 0:
            print("No Sentinel-2 images available for this date and location.")
            return None

        sen1_image = sen1.select(['B4', 'B8']).mosaic()
    else:
        sen1_image = sen1.select(['VV', 'VH']).mosaic()
    

    despeckled = sen1_image.focal_mean(100, 'square', 'meters')
    vv_dark = despeckled.select('VV').lt(-22)
    vh_dark = despeckled.select('VH').lt(-18)
    oil_spill_detection = vv_dark.And(vh_dark)

    mask = oil_spill_detection.updateMask(oil_spill_detection)
    area = mask.multiply(ee.Image.pixelArea().divide(1e6))
    oil_spill_area = ee.Number(
        area.reduceRegion(
            reducer=ee.Reducer.sum(),
            geometry=roi,
            scale=100
        ).values().get(0)
    ).getInfo()

    if oil_spill_area > 0:
        print(f"Detected Oil Spill Area (sq. km): {oil_spill_area}")

        despeckled_np = geemap.ee_to_numpy(despeckled, bands=['VV', 'VH'], region=roi, scale=100)

        # Ensure image preprocessing for models
        #processed_image = preprocess_image_for_model(despeckled_np)

        # Confirm using all three models
        if confirm_oil_spill(hybrid_model, unet_model, deeplab_model, despeckled_np):
            detected_spills.append(oil_spill_area)

            # oil_spill_vis_params = {
            #     'min': 0,
            #     'max': 1,
            #     'palette': ['blue', 'cyan', 'yellow', 'red']
            # }

            # Visualization
            Map = geemap.Map()
            Map.centerObject(roi)
            Map.addLayer(sen1_image, {'bands': ['VV', 'VH'], 'min': -30, 'max': 0}, f'Sentinel-1 Image {anomaly_date.getInfo()}')
            Map.addLayer(despeckled.clip(roi), {}, 'Despeckled Image', False)
            Map.addLayer(oil_spill_detection.clip(roi), {}, 'Oil Spill Detection', False)
            oil_spill_vector = mask.reduceToVectors(
                geometry=roi,
                scale=100
            )
            Map.addLayer(oil_spill_vector, {}, 'Oil Spill Vector', False)

    if detected_spills:
        print(f"Oil spills detected over the days: {detected_spills}")
        Map.addLayerControl()
        return Map
    else:
        print("No significant oil spills detected across the checked dates.")
        return None
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Iterate over each anomaly in the DataFrame and process
for index, row in anomalies_df.iterrows():
    result_map = process_anomaly(row)
    if result_map:
        display(result_map)  # This displays the map in interactive environments
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing anomaly at 29.60747, -89.88319 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 29.60596, -89.87661 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.54057, -78.80176 on 2024-01-23
# No significant oil spills detected across the checked dates.
# Processing anomaly at 25.80934, -80.16882 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 29.69324, -82.96946 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.76805, -80.13911 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.179 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.179 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.179 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.179 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.179 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.17917 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.179 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.785, -80.179 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 30.67853, -81.46401 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 30.67844, -81.46398 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 29.17218, -89.25847 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 28.86923, -89.43445 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 31.1555, -80.656 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 31.102, -80.79533 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 31.07917, -80.8645 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 48.49148, -122.67777 on 2024-01-23
# Detected Oil Spill Area (sq. km): 151.3272521247996
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 48.48982, -122.6766 on 2024-01-23
# Detected Oil Spill Area (sq. km): 152.48625949680277
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 48.60553, -122.81632 on 2024-01-23
# Detected Oil Spill Area (sq. km): 79.7724219461676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 48.56423, -122.72662 on 2024-01-23
# Detected Oil Spill Area (sq. km): 134.7591508878551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 48.49072, -122.6766 on 2024-01-23
# Detected Oil Spill Area (sq. km): 151.90300946812184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 48.49915, -122.82157 on 2024-01-23
# Detected Oil Spill Area (sq. km): 150.9288993331224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 20.89486, -156.46735 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 20.89487, -156.46725 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 20.8949, -156.46721 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 20.95049, -156.46274 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 20.6693, -155.81499 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 20.14053, -155.27485 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 20.02112, -155.15774 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 19.83246, -155.05504 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 32.66259, -117.12259 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 32.66248, -117.12252 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 27.64945, -96.0175 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.85396, -80.15765 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.33249, -80.25437 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 25.30886, -80.26932 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 49.35012, -124.35616 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 49.14437, -123.03289 on 2024-01-23
# Detected Oil Spill Area (sq. km): 6.139632661563668
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 48.93092, -125.33795 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 48.41461, -123.39823 on 2024-01-23
# Detected Oil Spill Area (sq. km): 205.92326025866114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 48.41514, -123.39537 on 2024-01-23
# Detected Oil Spill Area (sq. km): 208.35782864697856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.26668, -124.15175 on 2024-01-23
# Detected Oil Spill Area (sq. km): 15.18278679954246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.26696, -124.15211 on 2024-01-23
# Detected Oil Spill Area (sq. km): 15.152827400354344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.1238, -123.19268 on 2024-01-23
# Detected Oil Spill Area (sq. km): 115.36239461829564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.25869, -126.03897 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 49.15502, -125.90545 on 2024-01-23
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 48.65312, -123.39222 on 2024-01-23
# Detected Oil Spill Area (sq. km): 239.39436797826448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.05611, -123.32232 on 2024-01-23
# Detected Oil Spill Area (sq. km): 285.6389917403679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.28658, -123.10055 on 2024-01-23
# Detected Oil Spill Area (sq. km): 11.239537201857347
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.28629, -123.10046 on 2024-01-23
# Detected Oil Spill Area (sq. km): 11.218093691957687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.28627, -123.10041 on 2024-01-23
# Detected Oil Spill Area (sq. km): 11.202758598123433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.1758, -122.92588 on 2024-01-23
# Detected Oil Spill Area (sq. km): 0.7352855165307136
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49